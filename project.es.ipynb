# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
df = pd.read_csv('assets/real_estate.csv', sep=';')
df
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# TODO

# Encontrar el índice de la fila con el precio más alto
indice_mas_caro = df['price'].idxmax()

# Seleccionar la fila completa usando ese índice
casa_mas_cara = df.loc[indice_mas_caro]

# Imprimir la información de la casa
print("La casa más cara del dataset es:")
print(casa_mas_cara)
# Out:
# La casa más cara del dataset es:
# Unnamed: 0                                                      13111
# id_realEstates                                              132042636
# isNew                                                           False
# realEstate_name                            engel volkers torrelodones
# phone_realEstate                                          911798512.0
# url_inmueble        https://www.fotocasa.es/es/comprar/vivienda/vi...
# rooms                                                            19.0
# bathrooms                                                         NaN
# surface                                                           NaN
# price                                                         8500000
# date                                             2019-12-19T12:29:00Z
# description         El Palacio de El Enebral, la finca fue propied...
# address                                                   El Escorial
# ...

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# TODO

# Se hace corrección ya que mostraba el precio más barato de una cada = 0
# Se ajusta para dar la casa más barata con precio diferente de cero 

df_no_cero = df[df['price'] > 0]
precio_minimo_no_cero = df_no_cero['price'].min()
indice_min_no_cero = df_no_cero['price'].idxmin()
casa_mas_barata_no_cero = df.loc[indice_min_no_cero]
print(f"La casa más barata es: {casa_mas_barata_no_cero}")
# Out:
# La casa más barata es: Unnamed: 0                                                       7492
# id_realEstates                                              153977752
# isNew                                                           False
# realEstate_name                                       redpiso coslada
# phone_realEstate                                          910759552.0
# url_inmueble        https://www.fotocasa.es/es/comprar/vivienda/ma...
# rooms                                                             3.0
# bathrooms                                                         1.0
# surface                                                          80.0
# price                                                             600
# date                                             2019-12-24T12:56:00Z
# description         REDPISO COSLADA alquila vivienda en Ciudad 70,...
# address                                               Berlin, Coslada
# ...

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
# TODO

casa_mas_grande = df.loc[df[("surface")].idxmax()]
print('La casa mas grande es:\n', casa_mas_grande)
# Out:
# La casa mas grande es:
#  Unnamed: 0                                                       6795
# id_realEstates                                              153936192
# isNew                                                           False
# realEstate_name                               habitarium inmobiliaria
# phone_realEstate                                          916357732.0
# url_inmueble        https://www.fotocasa.es/es/comprar/vivienda/ma...
# rooms                                                             3.0
# bathrooms                                                         2.0
# surface                                                      249000.0
# price                                                          289000
# date                                             2019-12-25T18:30:00Z
# description         Zona Centro. Chalet pareado de esquina de 249m...
# address                                              Sevilla la Nueva
# ...

# %%
casa_mas_pequena = df.loc[df[("surface")].idxmin()]
print('La casa mas pequena es:\n', casa_mas_pequena)
# Out:
# La casa mas pequena es:
#  Unnamed: 0                                                        499
# id_realEstates                                              152817874
# isNew                                                           False
# realEstate_name                                              toledo21
# phone_realEstate                                          910757382.0
# url_inmueble        https://www.fotocasa.es/es/comprar/vivienda/ma...
# rooms                                                             1.0
# bathrooms                                                         1.0
# surface                                                          15.0
# price                                                           85000
# date                                     2019-12-28T19:04:44.6433814Z
# description         ¡NO BUSQUES MÁS, YA LA HAS ENCONTRADO! . \n \n...
# address                                 Calle Amparo,  Madrid Capital
# ...

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO

level5_populations_df = df['level5'].nunique()
print('En level5, hay: ', level5_populations_df, ' populations')
# Out:
# En level5, hay:  168  populations

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
# TODO

has_nas_df = df.isna().any().any()

if has_nas_df:
    print('El data set contiene NAs.')
else:
    print('El data set no contiene NAs.')
# Out:
# El data set contiene NAs.

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
# TODO

df_cleaned_columns =df.dropna(axis=0, how='all')
df_cleaned = df_cleaned_columns.dropna(axis=1, how='all')
df_cleaned
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
# TODO

mean_price_arroyomolinos = df_cleaned.groupby(['level5'])['price'].mean()
print('El precio medio de la población Arroyomolinos (Madrid) es: ', mean_price_arroyomolinos['Arroyomolinos (Madrid)'])
# Out:
# El precio medio de la población Arroyomolinos (Madrid) es:  294541.59854014596

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
# TODO: Code

from matplotlib import pyplot as plt

group_prices = df_cleaned.loc[df_cleaned['level5'] == 'Arroyomolinos (Madrid)']

plt.hist(group_prices['price'], bins=10)
plt.xlabel('Prices')
plt.ylabel('Frecuency')
plt.title('Prices of Population Arroyomolinos (Madrid)')
plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
# TODO

subset_df = df_cleaned[df_cleaned['level5'].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]
subset_df
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %%
valdemorillo_data = subset_df[subset_df['level5'] == 'Valdemorillo']
galapagar_data = subset_df[subset_df['level5'] == 'Galapagar']

#Calculate average prices
valdemorillo_avg_prices = valdemorillo_data['price'].mean()
galapagar_avg_prices = galapagar_data['price'].mean()

#Compare average prices
if valdemorillo_avg_prices == galapagar_avg_prices:
    print("Los precios medios en Valdemorillo y Galapagar son los mismos.")
else:
    print("Los precios medios en Valdemorillo y Galapagar son diferentes.")
# Out:
# Los precios medios en Valdemorillo y Galapagar son diferentes.

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# TODO

df['pps'] = df['price'] / df['surface']

# Calcular el promedio del precio por metro cuadrado para Valdemorillo y Galapagar
average_price_valdemorillo = df[df['level5'] == 'Valdemorillo']['pps'].mean()
average_price_galapagar = df[df['level5'] == 'Galapagar']['pps'].mean()
# Imprimir los resultados
print(f"Precio medio del metro cuadrado en Valdemorillo: {average_price_valdemorillo:.2f} €/m2")
print(f"Precio medio por metro cuadrado en Galapagar: {average_price_galapagar:.2f} €/m2")

# Comparar los promedios
if average_price_valdemorillo == average_price_galapagar:
    print("Conclusión: El precio medio del metro cuadrado es el mismo en Valdemorillo y Galapagar.")
else:
    print("Conclusión: El precio medio del metro cuadrado es diferente en Valdemorillo y Galapagar.")
# Out:
# Precio medio del metro cuadrado en Valdemorillo: 1317.95 €/m2
# Precio medio por metro cuadrado en Galapagar: 1606.32 €/m2
# Conclusión: El precio medio del metro cuadrado es diferente en Valdemorillo y Galapagar.

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
# TODO: Código

plt.scatter(df['surface'], df['price'])
plt.title('Relation between Surface and Price')
plt.xlabel('Surface (m2)')
plt.ylabel('Price (€)')
plt.grid(True)
plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
# TODO

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15335 entries, 0 to 15334
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        15335 non-null  int64
#  1   id_realEstates    15335 non-null  int64
#  2   isNew             15335 non-null  bool
#  3   realEstate_name   15325 non-null  object
#  4   phone_realEstate  14541 non-null  float64
#  5   url_inmueble      15335 non-null  object
#  6   rooms             14982 non-null  float64
#  7   bathrooms         14990 non-null  float64
#  8   surface           14085 non-null  float64
#  9   price             15335 non-null  int64
#  10  date              15335 non-null  object
#  11  description       15193 non-null  object
#  12  address           15335 non-null  object
#  13  country           15335 non-null  object
#  14  level1            15335 non-null  object
#  15  level2            15335 non-null  object
# ...

# %%
df["id_realEstates"].nunique()
# Out:
# 14217

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
# TODO

# Count the occurrences of each population
population_counts = df['level5'].value_counts()

# Find the population with the highest count
most_houses_population = population_counts.idxmax()
num_houses_in_population = population_counts.max()

# Print the result
print(f"La población con más casas es '{most_houses_population}' con {num_houses_in_population} casas.")
# Out:
# La población con más casas es ' Madrid Capital' con 6643 casas.

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
# TODO

# Specify the target populations
target_populations = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']

# Create a subset based on the target populations
subset_df = df[df['level5'].isin(target_populations)]

# Print the resulting subset
print(subset_df)
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
# TODO: Code

subset_df = df[df['level5'].isin(target_populations)]

median_prices = subset_df.groupby('level5')['price'].median()
median_prices.plot(kind='bar', rot=0, color='skyblue')
plt.title('Median Prices in South Madrid')
plt.xlabel('Population')
plt.ylabel('Median Price')
plt.show()

# %% [markdown]
# Madrid es la mas cara

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
# TODO

# Specify the target populations
target_populations = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']

# Create a subset based on the target populations
subset_df = df[df['level5'].isin(target_populations)]

# Calculate sample mean and variance for each variable
mean_price = subset_df['price'].mean()
variance_price = subset_df['price'].var()

mean_rooms = subset_df['rooms'].mean()
variance_rooms = subset_df['rooms'].var()

mean_surface_area = subset_df['surface'].mean()
variance_surface_area = subset_df['surface'].var()

mean_bathrooms = subset_df['bathrooms'].mean()
variance_bathrooms = subset_df['bathrooms'].var()

# Print the results
print(f"Sample Mean and Variance for Price: {mean_price}, {variance_price}")
print(f"Sample Mean and Variance for Rooms: {mean_rooms}, {variance_rooms}")
print(f"Sample Mean and Variance for Surface Area: {mean_surface_area}, {variance_surface_area}")
print(f"Sample Mean and Variance for Bathrooms: {mean_bathrooms}, {variance_bathrooms}")
# Out:
# Sample Mean and Variance for Price: 223094.48070562293, 14921367508.04902
# Sample Mean and Variance for Rooms: 3.0177383592017737, 0.7188858892927542
# Sample Mean and Variance for Surface Area: 111.75222363405337, 4263.051760316337
# Sample Mean and Variance for Bathrooms: 1.633221850613155, 0.5717968625577321

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
# TODO

# Specify the target populations
target_populations = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']

# Create a subset based on the target populations
subset_df = df[df['level5'].isin(target_populations)]

# Find the index of the most expensive house for each population
max_price_indices = subset_df.groupby('level5')['price'].idxmax()

# Print the most expensive house for each population
for index in max_price_indices:
    row = subset_df.loc[index]
    print(f"Population: {row['level5']}, Address: {row['address']}, Price: {row['price']}")
# Out:
# Population: Alcorcón, Address: Alcorcón, Price: 950000
# Population: Fuenlabrada, Address: Calle de Paulo Freire, 5, Fuenlabrada, Price: 490000
# Population: Getafe, Address: Getafe, Price: 1050000
# Population: Leganés, Address: Avenida Reina Sofía, Leganés, Price: 650000

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
# TODO

normalized_prices = {}
for population, data in subset_df.groupby('level5'):
    min_price = data['price'].min()
    max_price = data['price'].max()
    normalized_prices[population] = (data['price'] - min_price) / (max_price - min_price)

# Plot histograms
plt.figure(figsize=(10, 6))

for population, data in normalized_prices.items():
    plt.hist(data, bins=20, alpha=0.5, label=population)

plt.xlabel('Normalized Price')
plt.ylabel('Frequency')
plt.title('Normalized Prices Histograms for Different Populations')
plt.legend()
plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
# TODO

# Calculate the price per square meter (pps)
subset_df['pps'] = subset_df['price'] / subset_df['surface']

# Print the DataFrame with 'pps'
print(subset_df[['level5', 'price', 'surface', 'pps']])
# Out:
#             level5   price  surface          pps
# 1      Fuenlabrada   89000      NaN          NaN
# 3      Fuenlabrada   89000     86.0  1034.883721
# 85        Alcorcón  107000     50.0  2140.000000
# 94         Leganés  320000    120.0  2666.666667
# 109       Alcorcón  425000    142.0  2992.957746
# ...            ...     ...      ...          ...
# 15275  Fuenlabrada  138000     78.0  1769.230769
# 15291      Leganés  279000    110.0  2536.363636
# 15305  Fuenlabrada  170000     85.0  2000.000000
# 15322  Fuenlabrada  112000     91.0  1230.769231
# 15325  Fuenlabrada  215000     99.0  2171.717172
#
# [907 rows x 4 columns]
# /tmp/ipykernel_2936/3891110269.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
# TODO

# Create subplots
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))
fig.suptitle('Scatter Plots for Different Populations')

# Loop through populations and plot on subplots
for i, (population, data) in enumerate(subset_df.groupby('level5')):
    ax = axes[i // 2, i % 2]
    ax.scatter(data['surface'], data['price'], label=population)
    ax.set_xlabel('Surface Area')
    ax.set_ylabel('Price')
    ax.set_title(f'Scatter Plot - {population}')
    ax.legend()

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
